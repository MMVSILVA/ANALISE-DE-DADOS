# %% [markdown]
# <a href="https://colab.research.google.com/github/MMVSILVA/ANALISE-DE-DADOS/blob/main/_Aula_Python_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Integração SQL x Pyhton**

# %% [markdown]
# ## **Importando o necessário**

# %% [markdown]
# - username: sql10697620
#
# - password: MGbTUw14PG
#
# - host: sql10.freesqldatabase.com
#
# - port: 3306
#
# - database_name: sql10697620

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 649.8 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0

# %%
import pymysql
import pandas as pd

def query_to_dataframe(query):
    # Define as informações da conexão
    host = "sql10.freesqldatabase.com"
    port = 3306
    user = "sql10697620"
    password = "MGbTUw14PG"
    database = "sql10697620"

    # Conecta ao banco de dados
    connection = pymysql.connect(
        host=host,
        port=port,
        user=user,
        password=password,
        database=database
    )

    # Executa a query SQL e obtém os resultados em um DataFrame
    df = pd.read_sql_query(query, connection)

    # Fecha a conexão
    connection.close()

    # Retorna o DataFrame com os resultados da query
    return df

# %% [markdown]
# ## **Aplicando comandos**

# %% [markdown]
# ###**SELECT** é usado para mostrar nossos dados
#
# ### **FROM** é usado para especificar a tabela com que estamos trabalhando

# %% [markdown]
# ### **SELECT ***: Seleciona todas as colunas da tabela
#
# **Selecione todas as colunas de sua tabela:**

# %%
query = "SELECT * FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#     id                            nome        continente   populacao  \
# 0    1                  Estados Unidos  América do Norte   331449281
# 1    2                          Brasil    América do Sul   213993437
# 2    3                          Canadá  América do Norte    38307196
# 3    4                          México  América do Norte   130262216
# 4    5                       Argentina    América do Sul    45195774
# 5    6                        Colômbia    América do Sul    51230917
# 6    7                            Peru    América do Sul    32971846
# 7    8                           Chile    América do Sul    19116201
# 8    9                       Venezuela    América do Sul    28435943
# 9   10                            Cuba  América do Norte    11326616
# 10  11                          França            Europa    65273511
# 11  12                        Alemanha            Europa    83783942
# 12  13                     Reino Unido            Europa    68207116
# 13  14                          Itália            Europa    60550075
# 14  15                         Espanha            Europa    46733038
# 15  16                         Holanda            Europa    17141544
# 16  17                          Suécia            Europa    10099265
# 17  18                         Polônia            Europa    37846611
# 18  19                         Áustria            Europa     8917205
# 19  20                           Suíça            Europa     8715490
# 20  21                         Nigéria            África   206139587
# 21  22                         Etiópia            África   114963588
# 22  23                           Egito            África   104258327
# 23  24  República Democrática do Congo            África    89561404
# 24  25                        Tanzânia            África    59734218
# 25  26                   África do Sul            África    59308690
# 26  27                          Quênia            África    53771296
# 27  28                          Uganda            África    45741007
# 28  29                         Argélia            África    43851044
# 29  30                           Sudão            África    43849260
# 30  31                           China              Ásia  1439323776
# 31  32                           Índia              Ásia  1380004385
# 32  33                       Indonésia              Ásia   276361783
# 33  34                       Paquistão              Ásia   225199937
# 34  35                      Bangladesh              Ásia   164689383
# 35  36                           Japão              Ásia   125584838
# 36  37                       Filipinas              Ásia   111046913
# 37  38                          Vietnã              Ásia    98168856
# 38  39                             Irã              Ásia    83992949
# 39  40                         Turquia              Ásia    84734267
# 40  41                           China              Ásia  1439323776
# 41  42                           Índia              Ásia  1380004385
# 42  43                       Indonésia              Ásia   276361783
# 43  44                       Paquistão              Ásia   225199937
# 44  45                      Bangladesh              Ásia   164689383
# 45  46                           Japão              Ásia   125584838
# 46  47                       Filipinas              Ásia   111046913
# 47  48                          Vietnã              Ásia    98168856
# 48  49                             Irã              Ásia    83992949
# 49  50                         Turquia              Ásia    84734267
# 50  51                       Austrália           Oceania    25788272
# 51  52                   Nova Zelândia           Oceania     4822233
# 52  53                Papua-Nova Guiné           Oceania     8947024
# 53  54                            Fiji           Oceania      896445
# 54  55                   Ilhas Salomão           Oceania      699347
#
#     expectativa_vida  pib_per_capita
# 0              78.99        65297.52
# 1              75.88        14103.36
# 2              82.30        48637.76
# 3              75.20        10535.40
# 4              76.25        11683.85
# 5              77.29         6581.81
# 6              76.74         6572.92
# 7              80.18        22767.06
# 8              72.06         6231.17
# 9              78.80         9083.50
# 10             82.66        46403.25
# 11             80.99        55805.20
# 12             81.25        42943.90
# 13             83.51        35411.10
# 14             83.16        30461.55
# 15             82.78        57718.58
# 16             83.33        55995.74
# 17             78.73        16495.31
# 18             81.54        54547.74
# 19             83.78        82959.14
# 20             54.69         2687.49
# 21             66.60          953.39
# 22             72.40        13951.55
# 23             60.68          835.19
# 24             65.46         1156.42
# 25             64.13         6819.59
# 26             66.07         1697.95
# 27             63.28          826.06
# 28             76.88         4399.71
# 29             64.81         1528.04
# 30             76.92        10261.26
# 31             69.73         2104.39
# 32             71.73         4445.34
# 33             67.27         1425.98
# 34             72.60         2023.78
# 35             84.63        40236.01
# 36             71.23         3697.56
# 37             75.40         2711.03
# 38             75.88         5926.98
# 39             77.69        10498.64
# 40             76.92        10261.26
# 41             69.73         2104.39
# 42             71.73         4445.34
# 43             67.27         1425.98
# 44             72.60         2023.78
# 45             84.63        40236.01
# 46             71.23         3697.56
# 47             75.40         2711.03
# 48             75.88         5926.98
# 49             77.69        10498.64
# 50             83.44        54143.36
# 51             81.86        42929.89
# 52             64.80         2795.85
# 53             67.44         5274.21
# 54             73.37         2257.54

# %% [markdown]
# #### **SELECT Col1, Col2...** Seleciona colunas específicas
#
# **Selecione as colunas name e continent de sua tabela**

# %%
query= "SELECT nome, continente FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                               nome        continente
# 0                   Estados Unidos  América do Norte
# 1                           Brasil    América do Sul
# 2                           Canadá  América do Norte
# 3                           México  América do Norte
# 4                        Argentina    América do Sul
# 5                         Colômbia    América do Sul
# 6                             Peru    América do Sul
# 7                            Chile    América do Sul
# 8                        Venezuela    América do Sul
# 9                             Cuba  América do Norte
# 10                          França            Europa
# 11                        Alemanha            Europa
# 12                     Reino Unido            Europa
# 13                          Itália            Europa
# 14                         Espanha            Europa
# 15                         Holanda            Europa
# 16                          Suécia            Europa
# 17                         Polônia            Europa
# 18                         Áustria            Europa
# 19                           Suíça            Europa
# 20                         Nigéria            África
# 21                         Etiópia            África
# 22                           Egito            África
# 23  República Democrática do Congo            África
# 24                        Tanzânia            África
# 25                   África do Sul            África
# 26                          Quênia            África
# 27                          Uganda            África
# 28                         Argélia            África
# 29                           Sudão            África
# 30                           China              Ásia
# 31                           Índia              Ásia
# 32                       Indonésia              Ásia
# 33                       Paquistão              Ásia
# 34                      Bangladesh              Ásia
# 35                           Japão              Ásia
# 36                       Filipinas              Ásia
# 37                          Vietnã              Ásia
# 38                             Irã              Ásia
# 39                         Turquia              Ásia
# 40                           China              Ásia
# 41                           Índia              Ásia
# 42                       Indonésia              Ásia
# 43                       Paquistão              Ásia
# 44                      Bangladesh              Ásia
# 45                           Japão              Ásia
# 46                       Filipinas              Ásia
# 47                          Vietnã              Ásia
# 48                             Irã              Ásia
# 49                         Turquia              Ásia
# 50                       Austrália           Oceania
# 51                   Nova Zelândia           Oceania
# 52                Papua-Nova Guiné           Oceania
# 53                            Fiji           Oceania
# 54                   Ilhas Salomão           Oceania

# %% [markdown]
# #### **AS**: Após selecionar as colunas específicas, é possível renomeá-las
#
# **Selecione as colunas name e population de sua tabela, e as nomeie como País e População**

# %%
query = "SELECT nome AS 'País', continente AS 'Continente' from paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                               País        Continente
# 0                   Estados Unidos  América do Norte
# 1                           Brasil    América do Sul
# 2                           Canadá  América do Norte
# 3                           México  América do Norte
# 4                        Argentina    América do Sul
# 5                         Colômbia    América do Sul
# 6                             Peru    América do Sul
# 7                            Chile    América do Sul
# 8                        Venezuela    América do Sul
# 9                             Cuba  América do Norte
# 10                          França            Europa
# 11                        Alemanha            Europa
# 12                     Reino Unido            Europa
# 13                          Itália            Europa
# 14                         Espanha            Europa
# 15                         Holanda            Europa
# 16                          Suécia            Europa
# 17                         Polônia            Europa
# 18                         Áustria            Europa
# 19                           Suíça            Europa
# 20                         Nigéria            África
# 21                         Etiópia            África
# 22                           Egito            África
# 23  República Democrática do Congo            África
# 24                        Tanzânia            África
# 25                   África do Sul            África
# 26                          Quênia            África
# 27                          Uganda            África
# 28                         Argélia            África
# 29                           Sudão            África
# 30                           China              Ásia
# 31                           Índia              Ásia
# 32                       Indonésia              Ásia
# 33                       Paquistão              Ásia
# 34                      Bangladesh              Ásia
# 35                           Japão              Ásia
# 36                       Filipinas              Ásia
# 37                          Vietnã              Ásia
# 38                             Irã              Ásia
# 39                         Turquia              Ásia
# 40                           China              Ásia
# 41                           Índia              Ásia
# 42                       Indonésia              Ásia
# 43                       Paquistão              Ásia
# 44                      Bangladesh              Ásia
# 45                           Japão              Ásia
# 46                       Filipinas              Ásia
# 47                          Vietnã              Ásia
# 48                             Irã              Ásia
# 49                         Turquia              Ásia
# 50                       Austrália           Oceania
# 51                   Nova Zelândia           Oceania
# 52                Papua-Nova Guiné           Oceania
# 53                            Fiji           Oceania
# 54                   Ilhas Salomão           Oceania

# %% [markdown]
# #### **LIMIT:** Seleciona n primeiras linhas
#
# **Selecione as 5 primeiras linhas de sua tabela**

# %%
query = "SELECT * FROM paises LIMIT 5"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    id            nome        continente  populacao  expectativa_vida  \
# 0   1  Estados Unidos  América do Norte  331449281             78.99
# 1   2          Brasil    América do Sul  213993437             75.88
# 2   3          Canadá  América do Norte   38307196             82.30
# 3   4          México  América do Norte  130262216             75.20
# 4   5       Argentina    América do Sul   45195774             76.25
#
#    pib_per_capita
# 0        65297.52
# 1        14103.36
# 2        48637.76
# 3        10535.40
# 4        11683.85

# %% [markdown]
# ### **ORDER BY:** ordena a tabela inteira de acordo com uma coluna

# %% [markdown]
# #### **DESC:** ordena do maior para o menor, de forma descendente
#
# *Mostre os 10 países mais populosos do mundo de sua tabela, mostrando nome e população, de forma descrescente*

# %%
query = "SELECT nome, populacao FROM paises ORDER BY populacao desc limit 10"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#              nome   populacao
# 0           China  1439323776
# 1           China  1439323776
# 2           Índia  1380004385
# 3           Índia  1380004385
# 4  Estados Unidos   331449281
# 5       Indonésia   276361783
# 6       Indonésia   276361783
# 7       Paquistão   225199937
# 8       Paquistão   225199937
# 9          Brasil   213993437

# %% [markdown]
# #### **ASC:** ordena do menor para o maior, de forma ascendente
#
# *Mostre os 5 países mais pobres de sua tabela, mostrando seus respectivos nomes, continentes e gdp*

# %%
query = "SELECT nome, continente, pib_per_capita FROM paises ORDER BY pib_per_capita asc limit 5"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                              nome continente  pib_per_capita
# 0                          Uganda     África          826.06
# 1  República Democrática do Congo     África          835.19
# 2                         Etiópia     África          953.39
# 3                        Tanzânia     África         1156.42
# 4                       Paquistão       Ásia         1425.98

# %% [markdown]
# ### **WHERE** aplica filtros específicos, como =, >= e <=.

# %% [markdown]
# *Mostre todos os países asiáticos de sua tabela*

# %%
query = "SELECT nome from paises where continente = 'Asia' limit 5"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#          nome
# 0       China
# 1       Índia
# 2   Indonésia
# 3   Paquistão
# 4  Bangladesh

# %% [markdown]
# *Países com população superior ou igual a 200 milhões de habitantes de sua tabela*

# %%
query = "SELECT * FROM paises WHERE populacao >= 200e6 order by populacao desc"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#     id            nome        continente   populacao  expectativa_vida  \
# 0   31           China              Ásia  1439323776             76.92
# 1   41           China              Ásia  1439323776             76.92
# 2   42           Índia              Ásia  1380004385             69.73
# 3   32           Índia              Ásia  1380004385             69.73
# 4    1  Estados Unidos  América do Norte   331449281             78.99
# 5   43       Indonésia              Ásia   276361783             71.73
# 6   33       Indonésia              Ásia   276361783             71.73
# 7   34       Paquistão              Ásia   225199937             67.27
# 8   44       Paquistão              Ásia   225199937             67.27
# 9    2          Brasil    América do Sul   213993437             75.88
# 10  21         Nigéria            África   206139587             54.69
#
#     pib_per_capita
# 0         10261.26
# 1         10261.26
# 2          2104.39
# 3          2104.39
# 4         65297.52
# 5          4445.34
# 6          4445.34
# 7          1425.98
# 8          1425.98
# 9         14103.36
# 10         2687.49

# %% [markdown]
# *Países localizados na América do Sul de sua tabela*

# %%
query = "SELECT * FROM paises WHERE continente = 'America do Sul'"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    id       nome      continente  populacao  expectativa_vida  pib_per_capita
# 0   2     Brasil  América do Sul  213993437             75.88        14103.36
# 1   5  Argentina  América do Sul   45195774             76.25        11683.85
# 2   6   Colômbia  América do Sul   51230917             77.29         6581.81
# 3   7       Peru  América do Sul   32971846             76.74         6572.92
# 4   8      Chile  América do Sul   19116201             80.18        22767.06
# 5   9  Venezuela  América do Sul   28435943             72.06         6231.17

# %% [markdown]
# #### **OR** e **AND:** combinam filtros

# %% [markdown]
# *Apresente os países americanos de sua tabela*

# %%
query = """

SELECT * FROM paises
 WHERE continente = 'America do Sul'
  OR continente = 'America do Norte'
   OR continente = 'America Central'

"""
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    id            nome        continente  populacao  expectativa_vida  \
# 0   1  Estados Unidos  América do Norte  331449281             78.99
# 1   2          Brasil    América do Sul  213993437             75.88
# 2   3          Canadá  América do Norte   38307196             82.30
# 3   4          México  América do Norte  130262216             75.20
# 4   5       Argentina    América do Sul   45195774             76.25
# 5   6        Colômbia    América do Sul   51230917             77.29
# 6   7            Peru    América do Sul   32971846             76.74
# 7   8           Chile    América do Sul   19116201             80.18
# 8   9       Venezuela    América do Sul   28435943             72.06
# 9  10            Cuba  América do Norte   11326616             78.80
#
#    pib_per_capita
# 0        65297.52
# 1        14103.36
# 2        48637.76
# 3        10535.40
# 4        11683.85
# 5         6581.81
# 6         6572.92
# 7        22767.06
# 8         6231.17
# 9         9083.50

# %% [markdown]
# ### **COUNT** contabiliza linhas em uma coluna

# %% [markdown]
# *Veja quantas linhas as colunas de sua tabela possuem*

# %%
query = "SELECT COUNT(*) AS 'Qtd. de linhas' FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    Qtd. de linhas
# 0              55

# %% [markdown]
# #### **COUNT(DISTINCT)** contabiliza quantas variáveis possuem em uma coluna

# %% [markdown]
# *Mostre quantos continentes estão presentes na sua tabela*

# %%
query = "SELECT COUNT(DISTINCT continente) FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    COUNT(DISTINCT continente)
# 0                           6

# %% [markdown]
# ### **Operadores matemáticos**

# %% [markdown]
# #### **SUM** é o somatório de valores de uma coluna

# %% [markdown]
# *Quantos habitantes estão presentes em sua tabela?*

# %%
query = "SELECT SUM(populacao) FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    SUM(populacao)
# 0    1.015010e+10

# %% [markdown]
# #### **AVG:** Média de valores de uma coluna

# %% [markdown]
# *Qual o PIB médio mundial?*

# %%
query = "SELECT AVG(pib_per_capita) AS 'PIB médio' FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#       PIB médio
# 0  17984.618909

# %% [markdown]
# ### **GROUP BY** permite mostrar quantas vezes uma variável é repetida em uma coluna

# %% [markdown]
# **Mostre quantos países existem em cada continente**

# %%
query = "SELECT continente, COUNT(*) FROM paises GROUP BY continente"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#          continente  COUNT(*)
# 0            África        10
# 1  América do Norte         4
# 2    América do Sul         6
# 3              Ásia        20
# 4            Europa        10
# 5           Oceania         5

# %% [markdown]
# ## **Execícios - Revisão**

# %% [markdown]
# ### 1) Mostre todos os dados de sua tabela

# %%
query = "SELECT * FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#     id                            nome        continente   populacao  \
# 0    1                  Estados Unidos  América do Norte   331449281
# 1    2                          Brasil    América do Sul   213993437
# 2    3                          Canadá  América do Norte    38307196
# 3    4                          México  América do Norte   130262216
# 4    5                       Argentina    América do Sul    45195774
# 5    6                        Colômbia    América do Sul    51230917
# 6    7                            Peru    América do Sul    32971846
# 7    8                           Chile    América do Sul    19116201
# 8    9                       Venezuela    América do Sul    28435943
# 9   10                            Cuba  América do Norte    11326616
# 10  11                          França            Europa    65273511
# 11  12                        Alemanha            Europa    83783942
# 12  13                     Reino Unido            Europa    68207116
# 13  14                          Itália            Europa    60550075
# 14  15                         Espanha            Europa    46733038
# 15  16                         Holanda            Europa    17141544
# 16  17                          Suécia            Europa    10099265
# 17  18                         Polônia            Europa    37846611
# 18  19                         Áustria            Europa     8917205
# 19  20                           Suíça            Europa     8715490
# 20  21                         Nigéria            África   206139587
# 21  22                         Etiópia            África   114963588
# 22  23                           Egito            África   104258327
# 23  24  República Democrática do Congo            África    89561404
# 24  25                        Tanzânia            África    59734218
# 25  26                   África do Sul            África    59308690
# 26  27                          Quênia            África    53771296
# 27  28                          Uganda            África    45741007
# 28  29                         Argélia            África    43851044
# 29  30                           Sudão            África    43849260
# 30  31                           China              Ásia  1439323776
# 31  32                           Índia              Ásia  1380004385
# 32  33                       Indonésia              Ásia   276361783
# 33  34                       Paquistão              Ásia   225199937
# 34  35                      Bangladesh              Ásia   164689383
# 35  36                           Japão              Ásia   125584838
# 36  37                       Filipinas              Ásia   111046913
# 37  38                          Vietnã              Ásia    98168856
# 38  39                             Irã              Ásia    83992949
# 39  40                         Turquia              Ásia    84734267
# 40  41                           China              Ásia  1439323776
# 41  42                           Índia              Ásia  1380004385
# 42  43                       Indonésia              Ásia   276361783
# 43  44                       Paquistão              Ásia   225199937
# 44  45                      Bangladesh              Ásia   164689383
# 45  46                           Japão              Ásia   125584838
# 46  47                       Filipinas              Ásia   111046913
# 47  48                          Vietnã              Ásia    98168856
# 48  49                             Irã              Ásia    83992949
# 49  50                         Turquia              Ásia    84734267
# 50  51                       Austrália           Oceania    25788272
# 51  52                   Nova Zelândia           Oceania     4822233
# 52  53                Papua-Nova Guiné           Oceania     8947024
# 53  54                            Fiji           Oceania      896445
# 54  55                   Ilhas Salomão           Oceania      699347
#
#     expectativa_vida  pib_per_capita
# 0              78.99        65297.52
# 1              75.88        14103.36
# 2              82.30        48637.76
# 3              75.20        10535.40
# 4              76.25        11683.85
# 5              77.29         6581.81
# 6              76.74         6572.92
# 7              80.18        22767.06
# 8              72.06         6231.17
# 9              78.80         9083.50
# 10             82.66        46403.25
# 11             80.99        55805.20
# 12             81.25        42943.90
# 13             83.51        35411.10
# 14             83.16        30461.55
# 15             82.78        57718.58
# 16             83.33        55995.74
# 17             78.73        16495.31
# 18             81.54        54547.74
# 19             83.78        82959.14
# 20             54.69         2687.49
# 21             66.60          953.39
# 22             72.40        13951.55
# 23             60.68          835.19
# 24             65.46         1156.42
# 25             64.13         6819.59
# 26             66.07         1697.95
# 27             63.28          826.06
# 28             76.88         4399.71
# 29             64.81         1528.04
# 30             76.92        10261.26
# 31             69.73         2104.39
# 32             71.73         4445.34
# 33             67.27         1425.98
# 34             72.60         2023.78
# 35             84.63        40236.01
# 36             71.23         3697.56
# 37             75.40         2711.03
# 38             75.88         5926.98
# 39             77.69        10498.64
# 40             76.92        10261.26
# 41             69.73         2104.39
# 42             71.73         4445.34
# 43             67.27         1425.98
# 44             72.60         2023.78
# 45             84.63        40236.01
# 46             71.23         3697.56
# 47             75.40         2711.03
# 48             75.88         5926.98
# 49             77.69        10498.64
# 50             83.44        54143.36
# 51             81.86        42929.89
# 52             64.80         2795.85
# 53             67.44         5274.21
# 54             73.37         2257.54

# %% [markdown]
# ### 2) Mostre as colunas nome e população da sua tabela

# %%
query = "SELECT nome, populacao FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                               nome   populacao
# 0                   Estados Unidos   331449281
# 1                           Brasil   213993437
# 2                           Canadá    38307196
# 3                           México   130262216
# 4                        Argentina    45195774
# 5                         Colômbia    51230917
# 6                             Peru    32971846
# 7                            Chile    19116201
# 8                        Venezuela    28435943
# 9                             Cuba    11326616
# 10                          França    65273511
# 11                        Alemanha    83783942
# 12                     Reino Unido    68207116
# 13                          Itália    60550075
# 14                         Espanha    46733038
# 15                         Holanda    17141544
# 16                          Suécia    10099265
# 17                         Polônia    37846611
# 18                         Áustria     8917205
# 19                           Suíça     8715490
# 20                         Nigéria   206139587
# 21                         Etiópia   114963588
# 22                           Egito   104258327
# 23  República Democrática do Congo    89561404
# 24                        Tanzânia    59734218
# 25                   África do Sul    59308690
# 26                          Quênia    53771296
# 27                          Uganda    45741007
# 28                         Argélia    43851044
# 29                           Sudão    43849260
# 30                           China  1439323776
# 31                           Índia  1380004385
# 32                       Indonésia   276361783
# 33                       Paquistão   225199937
# 34                      Bangladesh   164689383
# 35                           Japão   125584838
# 36                       Filipinas   111046913
# 37                          Vietnã    98168856
# 38                             Irã    83992949
# 39                         Turquia    84734267
# 40                           China  1439323776
# 41                           Índia  1380004385
# 42                       Indonésia   276361783
# 43                       Paquistão   225199937
# 44                      Bangladesh   164689383
# 45                           Japão   125584838
# 46                       Filipinas   111046913
# 47                          Vietnã    98168856
# 48                             Irã    83992949
# 49                         Turquia    84734267
# 50                       Austrália    25788272
# 51                   Nova Zelândia     4822233
# 52                Papua-Nova Guiné     8947024
# 53                            Fiji      896445
# 54                   Ilhas Salomão      699347

# %% [markdown]
# ### 3) Mostre as colunas 'name' e 'continent', chamando elas de 'País' e 'Continente'.

# %%
# prompt:  Mostre as colunas 'name' e 'continent', chamando elas de 'País' e 'Continente'.

query = "SELECT nome AS 'País', continente AS 'Continente' FROM paises"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                               País        Continente
# 0                   Estados Unidos  América do Norte
# 1                           Brasil    América do Sul
# 2                           Canadá  América do Norte
# 3                           México  América do Norte
# 4                        Argentina    América do Sul
# 5                         Colômbia    América do Sul
# 6                             Peru    América do Sul
# 7                            Chile    América do Sul
# 8                        Venezuela    América do Sul
# 9                             Cuba  América do Norte
# 10                          França            Europa
# 11                        Alemanha            Europa
# 12                     Reino Unido            Europa
# 13                          Itália            Europa
# 14                         Espanha            Europa
# 15                         Holanda            Europa
# 16                          Suécia            Europa
# 17                         Polônia            Europa
# 18                         Áustria            Europa
# 19                           Suíça            Europa
# 20                         Nigéria            África
# 21                         Etiópia            África
# 22                           Egito            África
# 23  República Democrática do Congo            África
# 24                        Tanzânia            África
# 25                   África do Sul            África
# 26                          Quênia            África
# 27                          Uganda            África
# 28                         Argélia            África
# 29                           Sudão            África
# 30                           China              Ásia
# 31                           Índia              Ásia
# 32                       Indonésia              Ásia
# 33                       Paquistão              Ásia
# 34                      Bangladesh              Ásia
# 35                           Japão              Ásia
# 36                       Filipinas              Ásia
# 37                          Vietnã              Ásia
# 38                             Irã              Ásia
# 39                         Turquia              Ásia
# 40                           China              Ásia
# 41                           Índia              Ásia
# 42                       Indonésia              Ásia
# 43                       Paquistão              Ásia
# 44                      Bangladesh              Ásia
# 45                           Japão              Ásia
# 46                       Filipinas              Ásia
# 47                          Vietnã              Ásia
# 48                             Irã              Ásia
# 49                         Turquia              Ásia
# 50                       Austrália           Oceania
# 51                   Nova Zelândia           Oceania
# 52                Papua-Nova Guiné           Oceania
# 53                            Fiji           Oceania
# 54                   Ilhas Salomão           Oceania

# %% [markdown]
# ### 4) Mostre as 6 primeiras linhas da sua tabela

# %% [markdown]
# ### 5) Mostre em ordem alfabética decrescente (Z-A) 10 linhas da tabela, de acordo com os nomes dos países

# %%
# prompt: Mostre em ordem alfabética decrescente (Z-A) 10 linhas da tabela, de acordo com os nomes dos países

query = "SELECT * FROM paises ORDER BY nome desc LIMIT 10"
df = query_to_dataframe(query)
df
# Out:
# <ipython-input-37-3b30fc2aaa3c>:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    id       nome      continente  populacao  expectativa_vida  pib_per_capita
# 0  48     Vietnã            Ásia   98168856             75.40         2711.03
# 1  38     Vietnã            Ásia   98168856             75.40         2711.03
# 2   9  Venezuela  América do Sul   28435943             72.06         6231.17
# 3  28     Uganda          África   45741007             63.28          826.06
# 4  50    Turquia            Ásia   84734267             77.69        10498.64
# 5  40    Turquia            Ásia   84734267             77.69        10498.64
# 6  25   Tanzânia          África   59734218             65.46         1156.42
# 7  20      Suíça          Europa    8715490             83.78        82959.14
# 8  17     Suécia          Europa   10099265             83.33        55995.74
# 9  30      Sudão          África   43849260             64.81         1528.04

# %% [markdown]
# ### 6) Apresente os países que têm gdp maior que 1 trilhão de dólares

# %% [markdown]
# ### 7) Mostre os países do continente europeu e asiático

# %% [markdown]
# ### 8) Quantos continentes estão contidos na sua tabela?

# %% [markdown]
# ### 9) Faça a soma da população de todos os países

# %% [markdown]
# ### 10) Qual o país mais populoso?

# %% [markdown]
# ### 11) Mostre quantos países em cada continente possui mais de 200 milhões de habitantes
